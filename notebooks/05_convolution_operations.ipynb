# %% [markdown]
# # Convolution Operations from Scratch
#
# ## Objective
#
# Implement the fundamental convolution operations from scratch using NumPy to understand the core building blocks of Convolutional Neural Networks (CNNs).
#
# ## Topics
#
# - Convolution operation
# - Filters (kernels)
# - Output dimension calculation
# - Padding
# - Stride
# - Feature maps

# %%
# !pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.26.0-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.24 in C:\Users\Admin1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (2.5.1)
# Requirement already satisfied: scipy>=1.11.4 in C:\Users\Admin1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (1.18.0)
# Requirement already satisfied: networkx>=3.0 in C:\Users\Admin1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in C:\Users\Admin1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (12.3.0)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Downloading imageio-2.37.4-py3-none-any.whl.metadata (9.6 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2026.7.14-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: packaging>=21 in C:\Users\Admin1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from scikit-image) (26.2)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Downloading scikit_image-0.26.0-cp312-cp312-win_amd64.whl (11.9 MB)
#    ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.9 MB 8.3 MB/s eta 0:00:02
#    --------------------- ------------------ 6.3/11.9 MB 21.5 MB/s eta 0:00:01
#    ---------------------------------------  11.8/11.9 MB 23.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.9/11.9 MB 21.9 MB/s  0:00:00
# Downloading imageio-2.37.4-py3-none-any.whl (318 kB)
# Downloading lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Downloading tifffile-2026.7.14-py3-none-any.whl (270 kB)
# Installing collected packages: tifffile, lazy-loader, imageio, scikit-image
#
#    ---------------------------------------- 0/4 [tifffile]
#    -------------------- ------------------- 2/4 [imageio]
#    -------------------- ------------------- 2/4 [imageio]
#    ------------------------------ --------- 3/4 [scikit-image]
#    ------------------------------ --------- 3/4 [scikit-image]
#    ------------------------------ --------- 3/4 [scikit-image]
#    ------------------------------ --------- 3/4 [scikit-image]
#    ---------------------------------------- 4/4 [scikit-image]
#
# Successfully installed imageio-2.37.4 lazy-loader-0.5 scikit-image-0.26.0 tifffile-2026.7.14

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from skimage import data

# %%
image = np.array([
[3, 0, 1, 2, 7],
[1, 5, 8, 9, 3],
[2, 7, 2, 5, 1],
[0, 1, 3, 1, 7],
[4, 2, 1, 6, 2]])

kernel = np.array([
    [1, 0, 1],
    [0, 1, 0],
    [1, 0, 1]])

rgb_image = np.array([
    [[255, 0, 0],   [0, 255, 0],   [0, 0, 255]],   
    [[255, 255, 0], [0, 255, 255], [255, 0, 255]], 
    [[128, 128, 128],[255, 255, 255],[0, 0, 0]]   
], dtype=np.uint8)

print(rgb_image.shape)  
print(rgb_image)

print ("Shape de image :" , image.shape)
print ("Shape du kernel :" , kernel.shape)
# Out:
# (3, 3, 3)
# [[[255   0   0]
#   [  0 255   0]
#   [  0   0 255]]
#
#  [[255 255   0]
#   [  0 255 255]
#   [255   0 255]]
#
#  [[128 128 128]
#   [255 255 255]
#   [  0   0   0]]]
# Shape de image : (5, 5)
# Shape du kernel : (3, 3)

# %%
def compute_output_size(input_size, filter_size, padding, stride):
    return ((input_size + 2 * padding - filter_size) // stride) + 1

# %%
test_cases = [
    (5, 3, 0, 1),
    (5, 3, 1, 1),
    (7, 3, 0, 2),
    (32, 5, 2, 1),
    (64, 5, 0, 2),
]

for input_size, filter_size, padding, stride in test_cases:
    output = compute_output_size(input_size, filter_size, padding, stride)
    print(
        f"Input={input_size}, Kernel={filter_size}, Padding={padding}, "
        f"Stride={stride} -> OUTPUT={output}"
    )
# Out:
# Input=5, Kernel=3, Padding=0, Stride=1 -> OUTPUT=3
# Input=5, Kernel=3, Padding=1, Stride=1 -> OUTPUT=5
# Input=7, Kernel=3, Padding=0, Stride=2 -> OUTPUT=3
# Input=32, Kernel=5, Padding=2, Stride=1 -> OUTPUT=32
# Input=64, Kernel=5, Padding=0, Stride=2 -> OUTPUT=30

# %%
def convolution2d(image, kernel, padding="valid", stride=1, mode="constant"):

    fH, fW = kernel.shape

    if padding == "same":
        pad_h = (fH - 1) // 2
        pad_w = (fW - 1) // 2

        image = np.pad(
            image,
            ((pad_h, pad_h), (pad_w, pad_w)),
            mode=mode
        )

    elif isinstance(padding, int) and padding > 0:
        image = np.pad(
            image,
            ((padding, padding), (padding, padding)),
            mode=mode
        )

    H, W = image.shape

    out_H = ((H - fH) // stride) + 1
    out_W = ((W - fW) // stride) + 1

    output = np.zeros((out_H, out_W))

    for i in range(out_H):
        for j in range(out_W):
            region = image[
                i*stride:i*stride+fH,
                j*stride:j*stride+fW
            ]
            output[i, j] = np.sum(region * kernel)

    return output

# %%
image = np.array([
    [3,0,1,2,7],
    [1,5,8,9,3],
    [2,7,2,5,1],
    [0,1,3,1,7],
    [4,2,1,6,2]
])

kernel = np.array([
    [1,0,1],
    [0,1,0],
    [1,0,1]
])

feature_map = convolution2d(image, kernel)

print(feature_map)
# Out:
# [[13. 22. 20.]
#  [19. 18. 26.]
#  [10. 23.  7.]]

# %%
def convolution_rgb(image, filters, padding=0, stride=1):
    # image : (H, W, C)
    # filters : (num_filters, fH, fW, fC)
    
    if padding > 0:
        image = np.pad(image, ((padding, padding), (padding, padding), (0, 0)), mode="constant")
    
    H, W, C = image.shape
    num_filters, fH, fW, fC = filters.shape
    
    assert C == fC, "Kernel depth must match image depth."
    
    out_H = ((H - fH) // stride) + 1
    out_W = ((W - fW) // stride) + 1
    
    # output : (out_H, out_W, num_filters)
    output = np.zeros((out_H, out_W, num_filters))
    
    for n in range(num_filters): 
        kernel = filters[n]       
        for i in range(out_H):
            for j in range(out_W):
                result = 0
                for c in range(C): 
                    region = image[
                        i*stride:i*stride+fH,
                        j*stride:j*stride+fW,
                        c
                    ]
                    kernel_slice = kernel[:, :, c]
                    result += np.sum(region * kernel_slice)
                output[i, j, n] = result
    
    return output

# %%
def convolution_multiple_filters(image, filters, padding=0, stride=1):

    feature_maps = []

    for kernel in filters:

        feature_map = convolution_rgb(
            image,
            kernel,
            padding,
            stride
        )

        feature_maps.append(feature_map)

    return np.stack(feature_maps, axis=-1)

# %%
image = np.random.rand(32,32,3)

filters = np.random.rand(16,3,3,3)

output = convolution_rgb(image, filters)

print(output.shape)
# Out:
# (30, 30, 16)

# %%
image_gray = data.camera()
image_rgb = data.astronaut()

fig, axes = plt.subplots(1, 2, figsize=(3, 3))

axes[0].imshow(image_gray, cmap="gray")
axes[0].axis("off")
axes[0].set_title("Grayscale Image")

print ("Shape Img Grayscale :" , image_gray.shape)
print ("Shape Img RGB :" , image_rgb.shape)

axes[1].imshow(image_rgb)
axes[1].axis("off")
axes[1].set_title("RGB Image")

plt.tight_layout()
plt.show()
# Out:
# Shape Img Grayscale : (512, 512)
# Shape Img RGB : (512, 512, 3)

# %%
def apply_kernel_rgb(image, kernel):
    result = np.zeros_like(image)
    for c in range(3):
        result[:, :, c] = convolution2d(
            image[:, :, c],
            kernel,
            padding="same"
        )
    return np.clip(result, 0, 255).astype(np.uint8)

# %%
kernels = {
    'Blur': np.ones((13, 13)) / 100,  # Average kernel to blur the image
    'Sharpening': np.array([[0, -1, 0],
                            [-1, 5, -1],
                            [0, -1, 0]]),
    'Emboss': np.array([[-2, -1, 0],
                        [-1, 1, 1],
                        [0, 1, 2]]),
    'High pass filter': np.array([[-1, -1, -1],  # Kernel rejecting low frequencies (uniform color areas)
                                   [-1, 8, -1],
                                   [-1, -1, -1]])
}

fig, axes = plt.subplots(1, len(kernels), figsize=(16, 4))
for ax, (name, kernel) in zip(axes, kernels.items()):
    ax.imshow(kernel, cmap='gray', interpolation='nearest')
    ax.set_title(f'{name} filter')
    ax.axis('off')

for name, kernel in kernels.items():
    result_gray = convolution2d(image_gray, kernel, mode='same')
    result_rgb = apply_kernel_rgb(image_rgb, kernel)
    
    fig, axes = plt.subplots(1, 2, figsize=(3, 3))
    
    axes[0].imshow(result_gray, cmap="gray")
    print(f"{name} Result (Gray) ---- {name} Result (RGB)")
    axes[0].axis("off")
    
    axes[1].imshow(result_rgb)
    axes[1].axis("off")
    
    plt.tight_layout()
    plt.show()
# Out:
# Blur Result (Gray) ---- Blur Result (RGB)
# Sharpening Result (Gray) ---- Sharpening Result (RGB)
# Emboss Result (Gray) ---- Emboss Result (RGB)
# High pass filter Result (Gray) ---- High pass filter Result (RGB)

# %% [markdown]
# The core convolution operations were successfully implemented from scratch using NumPy.
# This notebook provides the foundation for understanding how Convolutional Neural Networks process images before building complete CNN models in the following notebooks.
